# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data

import seaborn as sns

# %% [markdown]
# ## Use the iris database to answer the following quesitons:

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ### What does the distribution of petal lengths look like?

# %%
sns.relplot(x='species', y='petal_length', data=iris)

# %%
sns.histplot(iris.petal_length)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='Count'>

# %% [markdown]
# ### Is there a correlation between petal length and petal width?

# %%
sns.relplot(x='petal_width', y='petal_length', data=iris)

# %% [markdown]
# ### Would it be reasonable to predict species based on sepal width and sepal length?

# %%
sns.relplot(x='petal_width', y='sepal_width',hue = "species", data=iris)

# %% [markdown]
# ### Which features would be best used to predict species?

# %%
sns.relplot(x='petal_width', y='sepal_width',hue = "species", data=iris)

# %%
sns.relplot(x='petal_length', y='sepal_width',hue = "species", data=iris)

# %%
sns.relplot(x="petal_length",y = "petal_width", hue = "species", data = iris)

# %%
sns.pairplot(iris,hue = "species")

# %% [markdown]
# ## Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe = sns.load_dataset('anscombe')

# %%
anscombe.groupby(by = ["x"]).agg(["mean","median","sum","count"])
# Out:
#               y
#            mean median    sum count
# x
# 4.0    4.250000   4.26  12.75     3
# 5.0    5.383333   5.68  16.15     3
# 6.0    6.483333   6.13  19.45     3
# 7.0    6.166667   6.42  18.50     3
# 8.0    7.066923   6.95  91.87    13
# 9.0    8.230000   8.77  24.69     3
# 10.0   8.213333   8.04  24.64     3
# 11.0   8.466667   8.33  25.40     3
# 12.0   9.373333   9.13  28.12     3
# 13.0   9.686667   8.74  29.06     3
# 14.0   8.966667   8.84  26.90     3
# 19.0  12.500000  12.50  12.50     1

# %%
anscombe.groupby(by = ["y"]).agg(["mean","median","sum","count"])
# Out:
#           x
#        mean median   sum count
# y
# 3.10    4.0    4.0   4.0     1
# 4.26    4.0    4.0   4.0     1
# 4.74    5.0    5.0   5.0     1
# 4.82    7.0    7.0   7.0     1
# 5.25    8.0    8.0   8.0     1
# 5.39    4.0    4.0   4.0     1
# 5.56    8.0    8.0   8.0     1
# 5.68    5.0    5.0   5.0     1
# 5.73    5.0    5.0   5.0     1
# 5.76    8.0    8.0   8.0     1
# 6.08    6.0    6.0   6.0     1
# 6.13    6.0    6.0   6.0     1
# 6.42    7.0    7.0   7.0     1
# 6.58    8.0    8.0   8.0     1
# 6.77    8.0    8.0   8.0     1
# 6.89    8.0    8.0   8.0     1
# 6.95    8.0    8.0   8.0     1
# 7.04    8.0    8.0   8.0     1
# 7.11    9.0    9.0   9.0     1
# 7.24    6.0    6.0   6.0     1
# 7.26    7.0    7.0   7.0     1
# 7.46   10.0   10.0  10.0     1
# 7.58   13.0   13.0  13.0     1
# 7.71    8.0    8.0   8.0     1
# 7.81   11.0   11.0  11.0     1
# 7.91    8.0    8.0   8.0     1
# 8.04   10.0   10.0  10.0     1
# 8.10   14.0   14.0  14.0     1
# ...

# %%
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %% [markdown]
# ### Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
sns.histplot(anscombe.x)
# Out:
# <AxesSubplot:xlabel='x', ylabel='Count'>

# %%
sns.histplot(anscombe.x, kde = True)
# Out:
# <AxesSubplot:xlabel='x', ylabel='Count'>

# %%
sns.histplot(anscombe.y)
# Out:
# <AxesSubplot:xlabel='y', ylabel='Count'>

# %%
sns.histplot(anscombe.y, kde = True)
# Out:
# <AxesSubplot:xlabel='y', ylabel='Count'>

# %%
sns.relplot(x='x', y='y', data=anscombe)

# %%
plt.figure(figsize=(12, 10))
plt.suptitle('Boxplots with Seaborn')

plt.subplot(221)
sns.boxplot(data=anscombe, y='y')
plt.title('A "typical" boxplot')

plt.subplot(222)
sns.boxplot(data=anscombe, x='x')
plt.title('Rotated 90$\degree$')

plt.subplot(223)
sns.boxplot(data=anscombe, y='y', x='x')
plt.title('Providing an x and y value groups the data')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# ## Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
insect_spray = data("InsectSprays")

# %%
sns.boxplot(data=insect_spray, x='count', y = "spray")
# Out:
# <AxesSubplot:xlabel='count', ylabel='spray'>

# %%
insect_spray.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
insect_spray.dtypes
# Out:
# count     int64
# spray    object
# dtype: object

# %% [markdown]
# ## Load the swiss dataset and read it's documentation. Create visualizations to answer the following questions:

# %%
swiss = data("swiss")

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
swiss.dtypes
# Out:
# Fertility           float64
# Agriculture         float64
# Examination           int64
# Education             int64
# Catholic            float64
# Infant.Mortality    float64
# dtype: object

# %% [markdown]
# ### Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
def is_catholic(num):
    if num >= 70:
        return True
    else:
        return False

# %%
mask = swiss.Catholic.apply(is_catholic)

# %%
swiss["is_catholic"] = mask

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
swiss.dtypes
# Out:
# Fertility           float64
# Agriculture         float64
# Examination           int64
# Education             int64
# Catholic            float64
# Infant.Mortality    float64
# is_catholic            bool
# dtype: object

# %% [markdown]
# ### Does whether or not a province is Catholic influence fertility?

# %%
sns.relplot(x="Fertility",y = "Catholic", hue = "is_catholic", data = swiss)

# %% [markdown]
# ### What measure correlates most strongly with fertility?

# %%
sns.relplot(x="Fertility",y = "Education", hue = "is_catholic", data = swiss)

# %%
swiss.drop(columns = "is_catholic")
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
sns.pairplot(swiss)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.regplot(x="Catholic",y = "Fertility", data = swiss)
# Out:
# <AxesSubplot:xlabel='Catholic', ylabel='Fertility'>

# %%
sns.regplot(x="Fertility",y = "Education", data = swiss)
# Out:
# <AxesSubplot:xlabel='Fertility', ylabel='Education'>

# %%
sns.regplot(x="Fertility",y = "Examination", data = swiss)
# Out:
# <AxesSubplot:xlabel='Fertility', ylabel='Examination'>

# %%
sns.regplot(x="Fertility",y = "Agriculture", data = swiss)
# Out:
# <AxesSubplot:xlabel='Fertility', ylabel='Agriculture'>

# %%
sns.pairplot(swiss, hue='is_catholic')
viz = sns.pairplot(swiss, hue='is_catholic')
viz = viz.map_upper(sns.regplot)

# %% [markdown]
# ## Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import host, user, password

# %%
def get_db_url(user,password,host,database):
    return (f"mysql+pymysql://{user}:{password}@{host}/{database}")

# %%
chipotle_url = get_db_url(user,password,host,database = "chipotle")

# %%
query = '''
SELECT *
FROM orders;
'''
chipotle = pd.read_sql(query,chipotle_url)
chipotle.head(5)
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
chipotle["item_price"] = chipotle["item_price"].str.lstrip("$")

# %%
chipotle = chipotle.astype({"item_price":"float64"})

# %%
fav_four = chipotle.groupby("item_name").sum().sort_values(by=["quantity"], ascending = False).head(4)

# %%
rev = fav_four.drop(columns = ["quantity"])

# %%
type(rev)
# Out:
# pandas.core.frame.DataFrame

# %%
best_sellers = chipotle.groupby('item_name').quantity.sum().nlargest(4)
best_sellers
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Name: quantity, dtype: int64

# %%
revenue = chipotle[chipotle.item_name.isin(best_sellers.index)].groupby('item_name').item_price.sum()
revenue = revenue.sort_values(ascending = False).reset_index()
revenue
# Out:
#              item_name  item_price
# 0         Chicken Bowl     7342.73
# 1      Chicken Burrito     5575.82
# 2        Steak Burrito     3851.43
# 3  Chips and Guacamole     2201.04

# %%
sns.relplot(x="item_name",y = "item_price", data = rev)

# %%
plt.figure(figsize = (8, 5))
sns.barplot(y = 'item_name', x = 'item_price', data = revenue)
# Out:
# <AxesSubplot:xlabel='item_price', ylabel='item_name'>

# %% [markdown]
# ## Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleep_study = data("sleepstudy",show_doc = True)
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# ...

# %%
sleep_study = data("sleepstudy")

# %%
sleep_study.head()
# Out:
#    Reaction  Days  Subject
# 1  249.5600     0      308
# 2  258.7047     1      308
# 3  250.8006     2      308
# 4  321.4398     3      308
# 5  356.8519     4      308

# %%
type(sleep_study)
# Out:
# pandas.core.frame.DataFrame

# %%
sns.pairplot(sleep_study)

# %%
sns.relplot(x ="Days",y = "Reaction",hue = "Subject", data = sleep_study)

# %%
sns.regplot(x ="Days",y = "Reaction",data = sleep_study)
# Out:
# <AxesSubplot:xlabel='Days', ylabel='Reaction'>
