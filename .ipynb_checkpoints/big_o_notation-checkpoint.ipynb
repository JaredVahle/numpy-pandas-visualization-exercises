# %%
import matplotlib.pyplot as plt
import math

# %%
n = list(range(1,11))

# %%
plt.plot(n)

# %%
plt.figure(figsize=(14, 6))
plt.plot(n,[0*y+1 for y in n],label = "O(0*n+1)")
plt.plot(n,[math.log(y) for y in n],label = "O(log(n))")
plt.plot(n,[y for y in n],label = "O(n)")
plt.plot(n,[y * math.log(y) for y in n],label = "O(n*log(n))")
plt.plot(n,[y**2 for y in n],label = "O(n**2)")
plt.plot(n,[2**y for y in n],label = "O(2**n)")
plt.plot(n,[math.factorial(y) for y in n],label = "O(fact(n))")
plt.plot(n,[y**y for y in n],label = "n**n")
plt.xlabel("Elements")
plt.ylabel("Operations")
plt.title("Big O notation")
lower = 0
upper = 10
plt.legend()
plt.show()
